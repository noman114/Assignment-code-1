# %%
import numpy as np


# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset =pd.read_csv("E:\\mine\\maximum.csv")
plt.xlabel("ann")
plt.ylabel("years")
# Out:
# Text(0, 0.5, 'years')

# %%
dataset
# Out:
#      Years  jan   feb   mar   apr   may   jun   jul   aug   sep   oct   nov  \
# 0   2012.0  7.5   7.2  12.1  10.2  15.0  15.9  17.9  19.4  15.9  11.6   8.7
# 1   2013.0  5.6   5.7   5.1  10.4  13.8  17.2  22.2  19.8  16.6  14.1   8.6
# 2   2014.0  7.4   7.8  10.5  13.2  15.2  18.6  21.2  18.0  18.2  14.3  10.4
# 3   2015.0  6.6   6.6   9.1  12.9  13.5  17.3  18.6  18.8  16.1  13.6  11.0
# 4   2016.0  7.3   7.0   8.9  10.6  15.9  17.8  19.3  19.7  18.3  13.4   8.1
# 5   2017.0  6.7   7.9  10.9  12.2  16.8  18.4  19.3  18.6  16.1  14.3   8.8
# 6   2018.0  6.7   5.3   6.9  12.0  17.2  19.9  22.6  19.3  16.4  13.3  10.1
# 7   2019.0  6.2  10.0  10.1  12.9  14.6  17.3  20.7  19.9  17.1  12.2   7.9
# 8   2020.0  8.3   8.0   9.3  14.2  16.7  18.3  18.3  19.9  17.1  12.4  10.7
# 9   2021.0  4.9   7.0   9.8  10.9  13.4  18.7  21.1  18.9  18.6  14.0  10.0
# 10     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
plt.hist(dataset["ann"] )
# Out:
# (array([2., 0., 0., 0., 1., 2., 2., 1., 1., 1.]),
#  array([12.35 , 12.469, 12.588, 12.707, 12.826, 12.945, 13.064, 13.183,
#         13.302, 13.421, 13.54 ]),
#  <BarContainer object of 10 artists>)

# %%
x=[
12.35,
12.36,
13.54,
12.93,
12.96,
13.12,
13.24,
13.1,
13.35,
12.95
]
y= [
2012,
2013,
2014,
2015,
2016,
2017,
2018,
2019,
2020,
2021
]
plt.scatter(x,y)

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x149eeac7190>,
# ...
#  [Text(1.0512979675681753, 0.32368593325478934, ''),
#   Text(0.6869672331046259, 0.8591135085892753, ''),
#   Text(0.05291976405510287, 1.0987263073997784, ''),
#   Text(-0.6138619532137746, 0.9127833819677974, ''),
#   Text(-1.0323209479124007, 0.37988611517301146, ''),
#   Text(-1.057729340439265, -0.30200768595172806, ''),
#   Text(-0.6702176729909899, -0.8722432406218708, ''),
#   Text(-0.0199510487935363, -1.0998190558687544, ''),
#   Text(0.6405229584148122, -0.8942764336286274, ''),
#   Text(1.0464906167045545, -0.33890616569977217, '')])

# %%
dataset =pd.read_csv("E:\\mine\\min tem.csv")

# %%
dataset
# Out:
#     year  jan  feb  mar  apr  may   jun   jul   aug   sep  oct  nov  dec  \
# 0   2011  0.4  2.6  1.8  5.7  6.8   8.2   9.7  10.2  10.0  7.9  5.8  2.0
# 1   2012  1.8  1.2  3.4  2.5  6.0   8.7  10.3  11.3   8.0  4.8  2.8  1.0
# 2   2013  1.0 -0.2 -0.7  2.2  5.2   8.5  11.9  11.4   8.9  8.3  2.4  2.7
# 3   2014  2.1  2.5  2.8  5.3  7.3   9.8  11.5   9.9   9.7  7.8  4.8  1.5
# 4   2015  0.8  0.5  1.9  3.0  5.7   8.1  10.2  10.6   7.6  6.3  5.3  5.2
# 5   2016  1.8  0.6  1.6  2.5  6.7  10.0  11.3  11.3  10.9  6.2  1.7  2.9
# 6   2017  1.0  2.6  3.6  3.8  7.4  10.5  11.0  10.5   9.0  8.1  2.7  1.3
# 7   2018  1.4 -0.7  0.7  4.8  6.9   9.8  11.9  11.1   8.4  5.8  4.5  3.2
# 8   2019  0.8  2.0  3.5  3.8  5.5   9.2  12.1  11.7   9.1  5.7  2.7  2.4
# 9   2020  3.0  2.1  1.9  4.0  6.1   9.8  10.4  11.9   8.6  6.4  4.8  1.9
# 10  2021 -0.5  1.1  3.0  0.5  4.9   9.8  12.1  11.1  10.7  7.8  4.0  2.8
#
#      win   spr    sum   aut   ann
# 0  -0.49  4.74   9.37  7.91  5.93
# ...

# %%
plt.hist(dataset["ann"] )
# Out:
# (array([2., 0., 1., 0., 3., 1., 1., 2., 0., 1.]),
#  array([5.16, 5.27, 5.38, 5.49, 5.6 , 5.71, 5.82, 5.93, 6.04, 6.15, 6.26]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x,y)
